# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EDA" data-toc-modified-id="EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Import-Packages" data-toc-modified-id="Import-Packages-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Packages</a></span></li><li><span><a href="#Explore-Dataset" data-toc-modified-id="Explore-Dataset-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Explore Dataset</a></span></li><li><span><a href="#Visualize-Global-Sales-through-features" data-toc-modified-id="Visualize-Global-Sales-through-features-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Visualize Global Sales through features</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Summary</a></span></li></ul></li></ul></div>

# %% [markdown]
# # EDA

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Explore Dataset

# %%
df = pd.read_csv('clean_df.csv')

# %%
df.head(50)
# Out:
#     rank                                          name platform  year  \
# 0      1                                    Wii Sports      Wii  2006
# 1      2                             Super Mario Bros.      NES  1985
# 2      3                                Mario Kart Wii      Wii  2008
# 3      4                             Wii Sports Resort      Wii  2009
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996
# 5      6                                        Tetris       GB  1989
# 6      7                         New Super Mario Bros.       DS  2006
# 7      8                                      Wii Play      Wii  2006
# 8      9                     New Super Mario Bros. Wii      Wii  2009
# 9     10                                     Duck Hunt      NES  1984
# 10    11                                    Nintendogs       DS  2005
# 11    12                                 Mario Kart DS       DS  2005
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16278 entries, 0 to 16277
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          16278 non-null  int64
#  1   name          16278 non-null  object
#  2   platform      16278 non-null  object
#  3   year          16278 non-null  int64
#  4   genre         16278 non-null  object
#  5   publisher     16278 non-null  object
#  6   na_sales      16278 non-null  float64
#  7   eu_sales      16278 non-null  float64
#  8   jp_sales      16278 non-null  float64
#  9   other_sales   16278 non-null  float64
#  10  global_sales  16278 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                rank          year      na_sales      eu_sales      jp_sales  \
# count  16278.000000  16278.000000  16278.000000  16278.000000  16278.000000
# mean    8291.720482   2006.417373      0.265192      0.147808      0.078893
# std     4791.725737      5.798835      0.821982      0.509495      0.311997
# min        1.000000   1981.000000      0.000000      0.000000      0.000000
# 25%     4135.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8295.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2016.000000     41.490000     29.020000     10.220000
#
#         other_sales  global_sales
# count  16278.000000  16278.000000
# mean       0.048456      0.540622
# std        0.190155      1.567561
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %% [markdown]
# Based on these statistics, we can see that 2006 had the most sales, national sales are half of the global sales.

# %% [markdown]
# ## Visualize Global Sales through features

# %%
from IPython.display import Image
Image(filename="/Users/majapedigo/Desktop/ Capstone Project II/Global Sales by Genre.png", width=300, height=150)

# %%
Image(filename="/Users/majapedigo/Desktop/ Capstone Project II/Global Sales by Year.png", width=300, height=150)

# %%
df.corr()
# Out:
#                   rank      year  na_sales  eu_sales  jp_sales  other_sales  \
# rank          1.000000  0.176170 -0.399888 -0.379347 -0.269584    -0.332958
# year          0.176170  1.000000 -0.089037  0.005923 -0.170973     0.041026
# na_sales     -0.399888 -0.089037  1.000000  0.769613  0.451865     0.635163
# eu_sales     -0.379347  0.005923  0.769613  1.000000  0.436364     0.726248
# jp_sales     -0.269584 -0.170973  0.451865  0.436364  1.000000     0.290534
# other_sales  -0.332958  0.041026  0.635163  0.726248  0.290534     1.000000
# global_sales -0.426806 -0.073831  0.941427  0.903464  0.612998     0.748165
#
#               global_sales
# rank             -0.426806
# year             -0.073831
# na_sales          0.941427
# eu_sales          0.903464
# jp_sales          0.612998
# other_sales       0.748165
# global_sales      1.000000

# %% [markdown]
# From the correlation, there is a decrease in sales over the years everywhere except in Europe.

# %%
Image(filename="/Users/majapedigo/Desktop/ Capstone Project II/Sales by Game and Platform (globally).png", width=600, height=150)

# %%
Image(filename="/Users/majapedigo/Desktop/ Capstone Project II/Top 10 Games (Globally).png", width=300, height=150)

# %%
Image(filename="/Users/majapedigo/Desktop/ Capstone Project II/Top 10 Platforms (Globally).png", width=300, height=150)

# %%
Image(filename="/Users/majapedigo/Desktop/ Capstone Project II/Top 10 Publishers (Globally).png", width=300, height=150)

# %% [markdown]
# ## Summary

# %% [markdown]
# In summary we can conclude that, globally:
#  - Action and Sports are the most popular genres.
#  - Wii Sports and Grand Theft Auto V are the most popular games.
#  - Wii is the most popular platform
#  - Nintendo and EA are the most successful publishers in terms of games sold.
#  - Year 2006 had the highest sales, according to the data available.
